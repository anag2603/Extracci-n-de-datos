# %%
filtro_h.to_csv("Filtro_h.csv")

# %%
# Filtrar registros con review_scores_cleanliness < 3 y review_scores_rating > 3
df["review_scores_cleanliness"] = pd.to_numeric(df["review_scores_cleanliness"], errors="coerce")
df["review_scores_rating"] = pd.to_numeric(df["review_scores_rating"], errors="coerce")
filtro_h = df[(df["review_scores_cleanliness"] < 3) & (df["review_scores_rating"] > 3)]
filtro_h

#Selecciona los registros donde review_scores_cleanliness sea menor que 3 y review_scores_rating sea mayor que 3.
# Out:
#                         id                                       listing_url  \
# 317                 871902               https://www.airbnb.com/rooms/871902
# 414                1108579              https://www.airbnb.com/rooms/1108579
# 1172               5590827              https://www.airbnb.com/rooms/5590827
# 1556               7465286              https://www.airbnb.com/rooms/7465286
# 1580               7738295              https://www.airbnb.com/rooms/7738295
# 1627               7819840              https://www.airbnb.com/rooms/7819840
# 2220              11174367             https://www.airbnb.com/rooms/11174367
# 2228              11225429             https://www.airbnb.com/rooms/11225429
# 3051              16412432             https://www.airbnb.com/rooms/16412432
# 3216              17550733             https://www.airbnb.com/rooms/17550733
# 3472              18804043             https://www.airbnb.com/rooms/18804043
# ...

# %%
filtro_g.to_csv("Filtro_g.csv")

# %%
# Convertir la columna 'bathrooms' a formato numérico
df["bathrooms"] = pd.to_numeric(df["bathrooms"], errors="coerce")
# Filtrar registros con 1 baño o superhost y que sean instant_bookable
filtro_g = df[((df["bathrooms"] == 1) | (df["host_is_superhost"] == "t")) & (df["instant_bookable"] == "t")]
filtro_g
# Out:
#                         id                                       listing_url  \
# 5                    68448                https://www.airbnb.com/rooms/68448
# 18                   81081                https://www.airbnb.com/rooms/81081
# 20                   85560                https://www.airbnb.com/rooms/85560
# 27                   30295                https://www.airbnb.com/rooms/30295
# 35                  135097               https://www.airbnb.com/rooms/135097
# ...                    ...                                               ...
# 14003  1247106541265894214  https://www.airbnb.com/rooms/1247106541265894214
# 14004  1247110237821753915  https://www.airbnb.com/rooms/1247110237821753915
# 14007  1247603814767312744  https://www.airbnb.com/rooms/1247603814767312744
# 14008  1247611373476346345  https://www.airbnb.com/rooms/1247611373476346345
# 14014  1242797685006849808  https://www.airbnb.com/rooms/1242797685006849808
#
# ...

# %%
filtro_f.to_csv("Filtro_f.csv")

# %%
# Filtrar registros con 4 camas o menos
df["beds"] = pd.to_numeric(df["beds"], errors="coerce")
filtro_f = df[df["beds"] <= 4]
filtro_f

#Selecciona los registros donde el número de camas (beds) es 4 o menos.
# Out:
#                         id                                       listing_url  \
# 0                    57049                https://www.airbnb.com/rooms/57049
# 1                    58780                https://www.airbnb.com/rooms/58780
# 2                    62613                https://www.airbnb.com/rooms/62613
# 3                    64014                https://www.airbnb.com/rooms/64014
# 4                    64245                https://www.airbnb.com/rooms/64245
# ...                    ...                                               ...
# 14012  1242619875270165606  https://www.airbnb.com/rooms/1242619875270165606
# 14013  1242745030641013657  https://www.airbnb.com/rooms/1242745030641013657
# 14014  1242797685006849808  https://www.airbnb.com/rooms/1242797685006849808
# 14015  1242815787146152998  https://www.airbnb.com/rooms/1242815787146152998
# 14016  1242827668492112621  https://www.airbnb.com/rooms/1242827668492112621
#
# ...

# %%
filtro_e.to_csv("Filtro_e.csv")

# %%
# Filtrar registros de tipo de cuarto específico
filtro_e = df[df["room_type"].isin(["Entire home/apt", "Private room"])]
filtro_e

#Selecciona los registros que tienen un tipo de cuarto específico, como "Entire home/apt" o "Private room"
# Out:
#                         id                                       listing_url  \
# 0                    57049                https://www.airbnb.com/rooms/57049
# 1                    58780                https://www.airbnb.com/rooms/58780
# 2                    62613                https://www.airbnb.com/rooms/62613
# 3                    64014                https://www.airbnb.com/rooms/64014
# 4                    64245                https://www.airbnb.com/rooms/64245
# ...                    ...                                               ...
# 14012  1242619875270165606  https://www.airbnb.com/rooms/1242619875270165606
# 14013  1242745030641013657  https://www.airbnb.com/rooms/1242745030641013657
# 14014  1242797685006849808  https://www.airbnb.com/rooms/1242797685006849808
# 14015  1242815787146152998  https://www.airbnb.com/rooms/1242815787146152998
# 14016  1242827668492112621  https://www.airbnb.com/rooms/1242827668492112621
#
# ...

# %%
filtro_d.to_csv("Filtro_d.csv")

# %%
# Filtrar registros con al menos 5 accommodates
df["accommodates"] = pd.to_numeric(df["accommodates"], errors="coerce")
filtro_d = df[df["accommodates"] >= 5]
filtro_d

#Selecciona los registros donde el valor de la columna accommodates es al menos 5.
# Out:
#                         id                                       listing_url  \
# 9                     9991                 https://www.airbnb.com/rooms/9991
# 16                   22677                https://www.airbnb.com/rooms/22677
# 19                   83614                https://www.airbnb.com/rooms/83614
# 27                   30295                https://www.airbnb.com/rooms/30295
# 30                   37554                https://www.airbnb.com/rooms/37554
# ...                    ...                                               ...
# 13971  1241102237180603217  https://www.airbnb.com/rooms/1241102237180603217
# 13978  1241819641376279369  https://www.airbnb.com/rooms/1241819641376279369
# 13979  1241903807338724655  https://www.airbnb.com/rooms/1241903807338724655
# 13983  1246375466752289965  https://www.airbnb.com/rooms/1246375466752289965
# 13987  1247022660041684348  https://www.airbnb.com/rooms/1247022660041684348
#
# ...

# %%
filtro_c.to_csv("Filtro_c.csv")

# %%
# Filtrar registros de hosts con respuesta en 1 día o menos
filtro_c = df[df["host_response_time"].str.contains("within a day|within an hour|within a few hours", na=False, case=False)]
filtro_c

#Utilizando la función str.contains para buscar las frases que indican tiempos de respuesta como "within a day", 
#"within an hour" y "within a few hours".
# Out:
#                         id                                       listing_url  \
# 0                    57049                https://www.airbnb.com/rooms/57049
# 1                    58780                https://www.airbnb.com/rooms/58780
# 2                    62613                https://www.airbnb.com/rooms/62613
# 3                    64014                https://www.airbnb.com/rooms/64014
# 4                    64245                https://www.airbnb.com/rooms/64245
# ...                    ...                                               ...
# 14006  1247573966059425584  https://www.airbnb.com/rooms/1247573966059425584
# 14007  1247603814767312744  https://www.airbnb.com/rooms/1247603814767312744
# 14010  1242136823326383374  https://www.airbnb.com/rooms/1242136823326383374
# 14012  1242619875270165606  https://www.airbnb.com/rooms/1242619875270165606
# 14014  1242797685006849808  https://www.airbnb.com/rooms/1242797685006849808
#
# ...

# %%
filtro_b.to_csv("Filtro_b.csv")

# %%
# Convertir 'host_since' a formato datetime
df["host_since"] = pd.to_datetime(df["host_since"], format="%d/%m/%Y", errors="coerce")
# Filtrar registros de hosts unidos antes del 1 de enero de 2019
filtro_b = df[df["host_since"] < pd.Timestamp("2019-01-01")]
filtro_b
# Out:
#                         id                                       listing_url  \
# 0                    57049                https://www.airbnb.com/rooms/57049
# 1                    58780                https://www.airbnb.com/rooms/58780
# 2                    62613                https://www.airbnb.com/rooms/62613
# 3                    64014                https://www.airbnb.com/rooms/64014
# 4                    64245                https://www.airbnb.com/rooms/64245
# ...                    ...                                               ...
# 14008  1247611373476346345  https://www.airbnb.com/rooms/1247611373476346345
# 14009  1247687868662918683  https://www.airbnb.com/rooms/1247687868662918683
# 14012  1242619875270165606  https://www.airbnb.com/rooms/1242619875270165606
# 14013  1242745030641013657  https://www.airbnb.com/rooms/1242745030641013657
# 14015  1242815787146152998  https://www.airbnb.com/rooms/1242815787146152998
#
# ...

# %%
filtro_a.to_csv("Filtro_a.csv")

# %%
# Obtener exactamente 5 host names diferentes
host_names = df["host_name"].dropna().unique()[:5]  # Selecciona 5 host names únicos
# Filtrar los registros de esos 5 host names
filtro_a = df[df["host_name"].isin(host_names)]
# Asegurarse de que solo hay 5 host names diferentes, si esto no existe en el codigo, se muestran mas de 5 registros.
filtro_a = filtro_a.groupby("host_name").filter(lambda x: len(x) > 0).head(5)
filtro_a

#groupby es una función de Pandas que se utiliza para agrupar datos según una o más columnas, lo que permite realizar
#operaciones específicas sobre cada grupo individualmente.
# Out:
#       id                         listing_url       scrape_id last_scraped  \
# 0  57049  https://www.airbnb.com/rooms/57049  20240918135550   2024-09-18
# 1  58780  https://www.airbnb.com/rooms/58780  20240918135550   2024-09-18
# 2  62613  https://www.airbnb.com/rooms/62613  20240918135550   2024-09-18
# 3  64014  https://www.airbnb.com/rooms/64014  20240918135550   2024-09-18
# 4  64245  https://www.airbnb.com/rooms/64245  20240918135550   2024-09-18
#
#         source                                               name  \
# 0  city scrape                  130 sqm with a view on Mauer Park
# 1  city scrape                  light quiet beautiful 4 room flat
# 2  city scrape                Super Apartment in Berlin/Kreuzberg
# 3  city scrape  Rooftop apt w/ a view, 2 bedrooms/bathrooms, s...
# 4  city scrape  Room w/ balcony and private bathroom in nice area
#
#                                          description  \
# 0  An apartment of 130 sqm right in the heart of ...
# ...

# %% [markdown]
# Filtro a

# %%
df= pd.read_csv('listings.csv/listings.csv')
df
# Out:
#                         id                                       listing_url  \
# 0                    57049                https://www.airbnb.com/rooms/57049
# 1                    58780                https://www.airbnb.com/rooms/58780
# 2                    62613                https://www.airbnb.com/rooms/62613
# 3                    64014                https://www.airbnb.com/rooms/64014
# 4                    64245                https://www.airbnb.com/rooms/64245
# ...                    ...                                               ...
# 14012  1242619875270165606  https://www.airbnb.com/rooms/1242619875270165606
# 14013  1242745030641013657  https://www.airbnb.com/rooms/1242745030641013657
# 14014  1242797685006849808  https://www.airbnb.com/rooms/1242797685006849808
# 14015  1242815787146152998  https://www.airbnb.com/rooms/1242815787146152998
# 14016  1242827668492112621  https://www.airbnb.com/rooms/1242827668492112621
#
# ...

# %%
df.info()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14017 entries, 0 to 14016
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            14017 non-null  int64
#  1   listing_url                                   14017 non-null  object
#  2   scrape_id                                     14017 non-null  int64
#  3   last_scraped                                  14017 non-null  object
#  4   source                                        14017 non-null  object
#  5   name                                          14017 non-null  object
#  6   description                                   13235 non-null  object
#  7   neighborhood_overview                         7044 non-null   object
#  8   picture_url                                   14017 non-null  object
# ...

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
